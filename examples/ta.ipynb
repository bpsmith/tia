# %% [markdown]
# # Examples using the technical analysis libraries (ta and talib_wrapper)

# %% [markdown]
# ## tia package (pure python)

# %%
import tia.analysis.ta as ta
from pandas.io.data import get_data_yahoo

# %%
pxs = get_data_yahoo(['MSFT', 'INTC'], start='1/1/2000')

# %%
#
# Convert Panel to a DataFrame for use with libraries
#
pxs_frame = pxs.to_frame().unstack().swaplevel(1, 0, axis=1).sortlevel(axis=1)
pxs_frame.tail()
# Out:
# minor        INTC                                             MSFT         \
#              Open   High    Low  Close    Volume  Adj Close   Open   High
# Date
# 2015-01-12  36.90  37.00  36.23  36.60  29400800      36.60  47.42  47.54
# 2015-01-13  36.87  37.49  36.29  36.50  31478000      36.50  46.97  47.91
# 2015-01-14  36.33  36.91  35.91  36.35  34250300      36.35  45.96  46.24
# 2015-01-15  36.53  36.88  36.03  36.19  47181800      36.19  46.22  46.38
# 2015-01-16  36.12  36.66  35.51  36.45  62764100      36.45  45.31  46.28
#
# minor
#               Low  Close    Volume  Adj Close
# Date
# 2015-01-12  46.36  46.60  23651900      46.60
# 2015-01-13  46.06  46.36  35270600      46.36
# 2015-01-14  45.62  45.96  29719600      45.96
# 2015-01-15  45.41  45.48  32742300      45.48
# 2015-01-16  45.17  46.24  35631100      46.24

# %%
close = pxs['Close']
close.tail()
# Out:
#              INTC   MSFT
# Date
# 2015-01-12  36.60  46.60
# 2015-01-13  36.50  46.36
# 2015-01-14  36.35  45.96
# 2015-01-15  36.19  45.48
# 2015-01-16  36.45  46.24

# %%
# moving average calculation
ta.SMA(close, 10).tail()
# Out:
#               INTC    MSFT
# Date
# 2015-01-12  36.389  46.727
# 2015-01-13  36.321  46.618
# 2015-01-14  36.280  46.512
# 2015-01-15  36.270  46.415
# 2015-01-16  36.279  46.363

# %%
# macd
ta.MACD(close).tail()
# Out:
#                  INTC                                                    MSFT  \
#             MACD_FAST  MACD_SLOW      MACD  MACD_SIGNAL  MACD_HIST  MACD_FAST
# Date
# 2015-01-12  36.488124  36.387856  0.100267     0.189835  -0.089567  46.894489
# 2015-01-13  36.489951  36.396163  0.093788     0.170625  -0.076838  46.812260
# 2015-01-14  36.468420  36.392744  0.075676     0.151636  -0.075959  46.681143
# 2015-01-15  36.425586  36.377726  0.047860     0.130881  -0.083020  46.496352
# 2015-01-16  36.429342  36.383079  0.046263     0.113957  -0.067694  46.456913
#
#
#             MACD_SLOW      MACD  MACD_SIGNAL  MACD_HIST
# Date
# 2015-01-12  47.108546 -0.214056    -0.194761  -0.019295
# 2015-01-13  47.053098 -0.240838    -0.203976  -0.036861
# 2015-01-14  46.972128 -0.290984    -0.221378  -0.069606
# 2015-01-15  46.861600 -0.365248    -0.250152  -0.115096
# 2015-01-16  46.815555 -0.358642    -0.271850  -0.086792

# %%
# rsi
ta.RSI(close, n=14).tail()
# Out:
#                  INTC       MSFT
# Date
# 2015-01-12  52.219266  46.388946
# 2015-01-13  51.230625  44.882868
# 2015-01-14  49.710321  42.411432
# 2015-01-15  48.071608  39.593937
# 2015-01-16  50.903920  45.740256

# %%
# determine when 50 crosses the 200
cross = ta.cross_signal(ta.sma(close.MSFT, 50), ta.sma(close.MSFT, 200))
cross.tail()
# Out:
# Date
# 2015-01-12    1
# 2015-01-13    1
# 2015-01-14    1
# 2015-01-15    1
# 2015-01-16    1
# dtype: float64

# %% [markdown]
# ## ta-lib wrapper
# Provide ability to call ta-lib with DataFrame or Series which may contain NaN values.

# %%
import tia.analysis.talib_wrapper as talib

# %%
talib.MACD(close).tail()
# Out:
#                 INTC                              MSFT
#                 MACD  MACD_SIGNAL  MACD_HIST      MACD  MACD_SIGNAL  MACD_HIST
# Date
# 2015-01-12  0.100267     0.189835  -0.089567 -0.214056    -0.194761  -0.019295
# 2015-01-13  0.093788     0.170625  -0.076838 -0.240838    -0.203976  -0.036861
# 2015-01-14  0.075676     0.151636  -0.075959 -0.290984    -0.221378  -0.069606
# 2015-01-15  0.047860     0.130881  -0.083020 -0.365248    -0.250152  -0.115096
# 2015-01-16  0.046263     0.113957  -0.067694 -0.358642    -0.271850  -0.086792

# %%
# average true range
talib.ATR(pxs_frame).tail()
# Out:
# minor           INTC      MSFT
# Date
# 2015-01-12  0.730920  0.945785
# 2015-01-13  0.764425  1.010371
# 2015-01-14  0.781252  0.991059
# 2015-01-15  0.786163  0.989555
# 2015-01-16  0.812151  0.998158

# %%
talib.RSI(close).tail()
# Out:
#                  INTC       MSFT
# Date
# 2015-01-12  52.219266  46.388946
# 2015-01-13  51.230625  44.882868
# 2015-01-14  49.710321  42.411432
# 2015-01-15  48.071608  39.593937
# 2015-01-16  50.903920  45.740256
